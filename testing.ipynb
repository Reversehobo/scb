# %%
#  VariableSelection:
#       type: object
#       required:
#         - "variableCode"
#         - "values"
#       properties:
#         variableCode:
#           type: string
#           description: The variable code.
#         codeList:
#           type: string
#           description: The identifier of the codelist that should be applied
#           nullable: true
#         outputValues:
#           $ref: '#/components/schemas/CodeListOutputValuesType'
#           description: If an codelist has been applied then how the resulting values should be constructed.
#           default: Aggregated
#           nullable: true
#         valueCodes:
#           type: array
#           description: An array of string that specifies wich values sould be selected. Either as value codes or value expressions
#           items:
#             type: string


{
    "selection": [
        {
            "variableCode": "VARIABLE-CODE-1",
            "valueCodes": ["ITEM-SELECTION-1-1", "ITEM-SELECTION-1-2"],
        },
        {
            "variableCode": "VARIABLE-CODE-1",
            "valueCodes": ["ITEM-SELECTION-2-1"],
            "codelList": "CODE-LIST-A",
            "outputValues": "single",
        },
    ]
}

# %%
{
            "id": "Alder",
            "label": "ålder",
            "type": "RegularVariable",
            "elimination": false,
            "values": [
                {
                    "code": "20-24",
                    "label": "20-24 år"
                },
                {
                    "code": "25-34",
                    "label": "25-34 år"
                },
                {
                    "code": "35-44",
                    "label": "35-44 år"
                },
                {
                    "code": "45-54",
                    "label": "45-54 år"
                },
                {
                    "code": "55-64",
                    "label": "55-64 år"
                },
                {
                    "code": "sam20-64",
                    "label": "samtliga 20-64 "
                }
            ]
        },
        {
            "id": "Kon",
            "label": "kön",
            "type": "RegularVariable",
            "elimination": false,
            "values": [
                {
                    "code": "1",
                    "label": "män"
                },
                {
                    "code": "2",
                    "label": "kvinnor"
                },
                {
                    "code": "1+2",
                    "label": "totalt"
                }
            ]
        },
        {
            "id": "Mottagar",
            "label": "mottagningsår",
            "type": "RegularVariable",
            "elimination": false,
            "values": [
                {
                    "code": "1997",
                    "label": "mottagningsår 1997"
                },
                {
                    "code": "1998",
                    "label": "mottagningsår 1998"
                },
                {
                    "code": "1999",
                    "label": "mottagningsår 1999"
                },
                {
                    "code": "2000",
                    "label": "mottagningsår 2000"
                },
                {
                    "code": "2001",
                    "label": "mottagningsår 2001"
                },
                {
                    "code": "2002",
                    "label": "mottagningsår 2002"
                },
                {
                    "code": "2003",
                    "label": "mottagningsår 2003"
                },
                {
                    "code": "2004",
                    "label": "mottagningsår 2004"
                },
                {
                    "code": "2005",
                    "label": "mottagningsår 2005"
                },
                {
                    "code": "2006",
                    "label": "mottagningsår 2006"
                },
                {
                    "code": "2007",
                    "label": "mottagningsår 2007"
                },
                {
                    "code": "2008",
                    "label": "mottagningsår 2008"
                },
                {
                    "code": "2009",
                    "label": "mottagningsår 2009"
                },
                {
                    "code": "2010",
                    "label": "mottagningsår 2010"
                },
                {
                    "code": "2011",
                    "label": "mottagningsår 2011"
                },
                {
                    "code": "2012",
                    "label": "mottagningsår 2012"
                },
                {
                    "code": "2013",
                    "label": "mottagningsår 2013"
                },
                {
                    "code": "2014",
                    "label": "mottagningsår 2014"
                },
                {
                    "code": "2015",
                    "label": "mottagningsår 2015"
                },
                {
                    "code": "2016",
                    "label": "mottagningsår 2016"
                },
                {
                    "code": "2017",
                    "label": "mottagningsår 2017"
                },
                {
                    "code": "2018",
                    "label": "mottagningsår 2018"
                },
                {
                    "code": "2019",
                    "label": "mottagningsår 2019"
                },
                {
                    "code": "2020",
                    "label": "mottagningsår 2020"
                },
                {
                    "code": "2021",
                    "label": "mottagningsår 2021"
                },
                {
                    "code": "2022",
                    "label": "mottagningsår 2022"
                }
            ]
        },
        {
            "id": "ContentsCode",
            "label": "tabellinnehåll",
            "type": "ContentsVariable",
            "values": [
                {
                    "baseperiod": "",
                    "adjustment": "None",
                    "measuringType": "Stock",
                    "preferedNumberOfDecimals": 0,
                    "priceType": "Undefined",
                    "unit": "andel, procent",
                    "refrencePeriod": "År",
                    "code": "000001C4",
                    "label": "Andel förvärvsarbetande kommunmottagna flyktingar och anhöriga, procent"
                }
            ]
        },
        {
            "id": "Tid",
            "label": "sysselsättningsår",
            "type": "TimeVariable",
            "timeUnit": "Annual",
            "firstPeriod": "1997",
            "lastPeriod": "2022",
            "values": [
                {
                    "code": "1997",
                    "label": "1997"
                },
                {
                    "code": "1998",
                    "label": "1998"
                },
                {
                    "code": "1999",
                    "label": "1999"
                },
                {
                    "code": "2000",
                    "label": "2000"
                },
                {
                    "code": "2001",
                    "label": "2001"
                },
                {
                    "code": "2002",
                    "label": "2002"
                },
                {
                    "code": "2003",
                    "label": "2003"
                },
                {
                    "code": "2004",
                    "label": "2004"
                },
                {
                    "code": "2005",
                    "label": "2005"
                },
                {
                    "code": "2006",
                    "label": "2006"
                },
                {
                    "code": "2007",
                    "label": "2007"
                },
                {
                    "code": "2008",
                    "label": "2008"
                },
                {
                    "code": "2009",
                    "label": "2009"
                },
                {
                    "code": "2010",
                    "label": "2010"
                },
                {
                    "code": "2011",
                    "label": "2011"
                },
                {
                    "code": "2012",
                    "label": "2012"
                },
                {
                    "code": "2013",
                    "label": "2013"
                },
                {
                    "code": "2014",
                    "label": "2014"
                },
                {
                    "code": "2015",
                    "label": "2015"
                },
                {
                    "code": "2016",
                    "label": "2016"
                },
                {
                    "code": "2017",
                    "label": "2017"
                },
                {
                    "code": "2018",
                    "label": "2018"
                },
                {
                    "code": "2019",
                    "label": "2019"
                },
                {
                    "code": "2020",
                    "label": "2020"
                },
                {
                    "code": "2021",
                    "label": "2021"
                },
                {
                    "code": "2022",
                    "label": "2022"
                }
            ]
        }

# %%
import json
import requests


SESSION = requests.Session()

BASE_URL = "https://api.scb.se/ov0104/v2beta/api/v2"
DEFAULT_LANG = "sv"  # Default language currently "sv" and "en" is supported
DEFAULT_FORMAT = "json-stat2"  # Default format for data response
CONFIG = None


def get_config() -> dict:
    """Get the configuration and set it as a global variable."""
    global CONFIG
    if CONFIG is None:
        response = SESSION.get(BASE_URL + "/config")
        CONFIG = response.json()
    return CONFIG


def get_folder(folder_id: str = "", lang: str = DEFAULT_LANG) -> dict:
    """Get the folder information for a specific folder ID."""
    response = SESSION.get(f"{BASE_URL}/navigation/{folder_id}", params={"lang": lang})
    return response.json()


get_config()


def get_tables(
    lang: str = DEFAULT_LANG,
    query: str = None,
    past_days: int = None,
    include_discontinued: bool = False,
    page_number: int = 1,
    page_size: int = 50,
) -> dict:
    """
    Fetch available tables with various filter options.

    Args:
        lang: The language for the response (default is 'en').
        query: Search criteria to filter tables by name or other attributes.
        past_days: Filters tables that were updated in the last N days.
        include_discontinued: Whether to include discontinued tables (default is False).
        page_number: Pagination parameter to fetch a specific page (default is 1).
        page_size: Pagination parameter to specify the number of tables per page (default is 50).

    Returns:
        A dictionary of available tables matching the search criteria.
    """
    url = f"{BASE_URL}/tables"
    params = {
        "lang": lang,
        "query": query,
        "pastDays": past_days,
        "includeDiscontinued": str(
            include_discontinued
        ).lower(),  # API expects a string 'true' or 'false'
        "pageNumber": page_number,
        "pageSize": page_size,
    }

    # Remove None values from the params dictionary
    params = {k: v for k, v in params.items() if v is not None}

    response = SESSION.get(url, params=params)
    return response.json()


def get_data(
    table_id: str,
    query: dict = None,
    lang: str = DEFAULT_LANG,
    format: str = DEFAULT_FORMAT,
) -> dict:
    """
    Fetch data for a specific table.

    Args:
        table_id: The ID of the table to fetch data from.
        query: The query to filter the data.
        lang: The language for the response (default is 'en').
        format: The format for the data response (default is 'json').
    """

    url = f"{BASE_URL}/tables/{table_id}/data"
    params = {"lang": lang, "outputFormat": format}
    response = SESSION.post(url, params=params, json=query)

    if "json" in response.headers["Content-Type"]:
        return response.json()
    else:
        return response.text

# %%
import json
from request_builder import get_queries
import time
import csv
from io import StringIO


def combine_csv_strings(csv_strings: list[str]) -> str:
    output = []
    for i, csv_string in enumerate(csv_strings):
        reader = csv.reader(StringIO(csv_string))
        if i == 0:
            output.extend(reader)
        else:
            output.extend(row for j, row in enumerate(reader) if j > 0)

    result = StringIO()
    writer = csv.writer(result)
    writer.writerows(output)
    return result.getvalue()


# from . import SESSION
import requests

SESSION = requests.Session()


BASE_URL = "https://api.scb.se/ov0104/v2beta/api/v2"
DEFAULT_LANG = "sv"  # Default language currently "sv" and "en" is supported
DEFAULT_FORMAT = "json"  # Default format for data response
CONFIG = None
PAGE_SIZE = 5000


def _simplify_string(string: str) -> str:
    """Simplify a string by stripping, removing spaces, and lowercasing."""
    return string.strip().replace(" ", "").lower()


def _compare_strings(string: str, *args: str) -> bool:
    """Returns True if the string is equal to any of the given arguments."""
    simple_string = _simplify_string(string)
    for arg in args:
        if simple_string == _simplify_string(arg):
            return True
    return False


def get_config() -> dict:
    """Get the configuration and set it as a global variable."""
    global CONFIG
    if CONFIG is None:
        response = SESSION.get(BASE_URL + "/config")
        CONFIG = response.json()
    return CONFIG


def save_csv(data: str, file_name: str) -> None:
    """Save the data as a CSV file."""
    with open(file_name, "w", encoding="utf-8", newline="") as file:
        file.write(data)


def get_folder(folder_id: str = "", lang: str = DEFAULT_LANG) -> dict:
    """Get the folder information for a specific folder ID."""
    response = SESSION.get(f"{BASE_URL}/navigation/{folder_id}", params={"lang": lang})
    return response.json()


def get_tables(
    lang: str = DEFAULT_LANG,
    query: str = None,
    past_days: int = None,
    include_discontinued: bool = True,
) -> dict:
    """
    Fetch available tables with various filter options.

    Args:
        lang: The language for the response (default is 'en').
        query: Search criteria to filter tables by name or other attributes.
        past_days: Filters tables that were updated in the last N days.
        include_discontinued: Whether to include discontinued tables (default is False).

    Returns:
        A dictionary of available tables matching the search criteria.
    """
    url = f"{BASE_URL}/tables"
    params = {
        "lang": lang,
        "query": query,
        "pastDays": past_days,
        "includeDiscontinued": str(
            include_discontinued
        ).lower(),  # API expects a string 'true' or 'false'
        "pageNumber": 1,
        "pageSize": PAGE_SIZE,
    }

    # Remove None values from the params dictionary
    params = {k: v for k, v in params.items() if v is not None}

    response = SESSION.get(url, params=params)
    response_dict = response.json()
    tables = response_dict["tables"]
    # remove the links and type element from each table, also remove description if empty string
    for table in tables:
        table.pop("links", None)
        table.pop("type", None)
        if table["description"] == "":
            table.pop("description", None)

    return tables


def get_metadata(table_id: str, lang: str = DEFAULT_LANG) -> dict:
    """
    Fetch metadata for a specific table.

    Args:
        table_id: The ID of the table to fetch metadata for.
        lang: The language for the response. Optional.
    """
    url = f"{BASE_URL}/tables/{table_id}/metadata"
    params = {"lang": lang}
    response = SESSION.get(url, params=params)
    return response.json()


def get_variables(table_id: str, lang: str = DEFAULT_LANG) -> dict:
    """
    Fetch the variables for a specific table.

    Args:
        table_id: The table ID to fetch variables for.
        lang: The language for the response (default is 'en').

    Returns:
        A dictionary of variables for the specified table.
    """
    metadata = get_metadata(table_id, lang)
    return metadata["variables"]


def get_data(
    table_id: str, lang: str = DEFAULT_LANG, format: str = DEFAULT_FORMAT, **kwargs
):
    """
    Fetch data for a specific table.

    Args:
        table_id: The ID of the table to fetch data from.
        lang: The language for the response (default is 'en').
        format: The format for the data response (default is 'json').
        kwargs: The query to filter the data.

    Returns:
        A dictionary of data for the specified table.
    """
    metadata = get_metadata(table_id, lang)
    variables = metadata["variables"]
    query = {"selection": []}

    for kwarg in kwargs:
        for variable in variables:
            # if variable["label"] == kwarg or variable["id"] == kwarg:
            if _compare_strings(kwarg, variable["label"], variable["id"]):
                input_values = kwargs[kwarg]

                query["selection"].append(
                    {
                        "variableCode": variable["id"],
                        "valueCodes": [
                            value["code"]
                            for value in variable["values"]
                            if _compare_strings(value["label"], *input_values)
                            or _compare_strings(value["code"], *input_values)
                        ],
                    }
                )

    url = f"{BASE_URL}/tables/{table_id}/data"
    params = {"lang": lang, "outputFormat": format}
    response = SESSION.post(url, params=params, json=query)

    if "json" in response.headers["Content-Type"]:
        return response.json()
    else:
        return response.text


def get_all_data(table_id: str, lang: str = DEFAULT_LANG, file_name: str = None):
    """
    Fetch all data for a specific table.

    Args:
        table_id: The ID of the table to fetch data from.
        lang: The language for the response (default is 'sv').
        file_name: The name of the file to save the data to (optional).
    """

    variables = get_variables(table_id, lang)
    limit = CONFIG["maxDataCells"]
    min_request_interval = CONFIG["timeWindow"] / CONFIG["maxCallsPerTimeWindow"] + 0.1
    last_request_time = time.time()

    simple_variables = {}
    for variable in variables:
        simple_variables[variable["id"]] = [
            value["code"] for value in variable["values"]
        ]

    queries = get_queries(simple_variables, limit)

    data = []
    url = f"{BASE_URL}/tables/{table_id}/data"
    params = {"lang": lang, "outputFormat": "csv2"}

    data = []

    for query in queries:
        current_time = time.time()
        if current_time - last_request_time < min_request_interval:
            time.sleep(min_request_interval - (current_time - last_request_time))
        last_request_time = time.time()

        response = SESSION.post(url, params=params, json=query)
        data.append(response.text)

    if file_name:
        save_csv(combine_csv_strings(data), file_name)

    return combine_csv_strings(data)


table_id = "TAB1267"
file_name = f"C:/Users/Admin/PYPI/scb/examples/{table_id}_all2.csv"
get_all_data(table_id, file_name=file_name)

# tables = get_tables(lang="sv")
# with open("tables.json", "w", encoding="utf-8") as file:
#     json.dump(tables, file, ensure_ascii=False, indent=4)

# table_id = "TAB3966"
# data = get_data(
#     table_id,
#     lang="sv",
#     format="json-stat",
#     ålder=["20-24", "25-34"],
#     Kon=["1", "totalt"],
#     Mottagar=["2010", "2011"],
#     tabellinnehåll=["000001C4"],
#     Tid=["2010", "2011"],
# )
# print(json.dumps(data, indent=2))

# config = get_config()
# # formats = []
# # for format in config["dataFormats"]:
# #     formats.append(format)

# table_id = "TAB3940"
# for format in config["dataFormats"]:
#     data = get_data(table_id, lang="sv", format=format)

# for format in config["dataFormats"]:
#     data = get_data(table_id, lang="sv", format=format)

# for format in config["dataFormats"]:
#     data = get_data(table_id, lang="sv", format=format)


# for format in formats:
#     # skip if json or csv is not in format
#     if "json" not in format and "csv" not in format:
#         continue
#     data = get_data(table_id, lang="sv", format=format)
#     file_name = f"C:/Users/Admin/PYPI/scb/examples/TAB3940/_{format}_"
#     if "json" in format:
#         file_name += ".json"
#         with open(file_name, "w", encoding="utf-8") as file:
#             json.dump(data, file, ensure_ascii=False, indent=4)
#     elif "csv" in format:
#         file_name += ".csv"
#         with open(file_name, "w", encoding="utf-8") as file:
#             file.write(data)

# %%
table_id = "TAB3966"
data = get_data(table_id, format="csv")
print(data)
# Out:
# "ålder","kön","mottagningsår","Andel förvärvsarbetande kommunmottagna flyktingar och anhöriga, procent 2022"
# "20-24 år","män","mottagningsår 1997",..
# "20-24 år","kvinnor","mottagningsår 1997",..
# "20-24 år","totalt","mottagningsår 1997",..
# "25-34 år","män","mottagningsår 1997",79.9
# "25-34 år","kvinnor","mottagningsår 1997",82.9
# "25-34 år","totalt","mottagningsår 1997",81.3
# "35-44 år","män","mottagningsår 1997",82.6
# "35-44 år","kvinnor","mottagningsår 1997",83.1
# "35-44 år","totalt","mottagningsår 1997",82.8
# "45-54 år","män","mottagningsår 1997",76.2
# "45-54 år","kvinnor","mottagningsår 1997",74.8
# "45-54 år","totalt","mottagningsår 1997",75.5
# "55-64 år","män","mottagningsår 1997",67.7
# "55-64 år","kvinnor","mottagningsår 1997",60.7
# "55-64 år","totalt","mottagningsår 1997",64.5
# "samtliga 20-64 ","män","mottagningsår 1997",76.6
# "samtliga 20-64 ","kvinnor","mottagningsår 1997",75.7
# "samtliga 20-64 ","totalt","mottagningsår 1997",76.2

# %%
table_id = "TAB3966"
data = get_data(table_id, format="json")
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# {
#   "columns": [
#     {
#       "code": "Alder",
#       "text": "ålder",
#       "type": "d"
#     },
#     {
#       "code": "Kon",
#       "text": "kön",
#       "type": "d"
#     },
#     {
#       "code": "Mottagar",
#       "text": "mottagningsår",
#       "type": "d"
#     },
#     {
#       "code": "Tid",
#       "text": "sysselsättningsår",
#       "type": "t"
#     },
#     {
#       "code": "000001C4",
#       "text": "Andel förvärvsarbetande kommunmottagna flyktingar och anhöriga, procent",
#       "type": "c"
#     }
#   ],
#   "comments": [],
#   "data": [
#     {
#       "key": [
#         "20-24",
#         "1",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         ".."
#       ]
#     },
#     {
#       "key": [
#         "20-24",
#         "2",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         ".."
#       ]
#     },
#     {
#       "key": [
#         "20-24",
#         "1+2",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         ".."
#       ]
#     },
#     {
#       "key": [
#         "25-34",
#         "1",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         "79.9"
#       ]
#     },
#     {
#       "key": [
#         "25-34",
#         "2",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         "82.9"
#       ]
#     },
#     {
#       "key": [
#         "25-34",
#         "1+2",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         "81.3"
#       ]
#     },
#     {
#       "key": [
#         "35-44",
#         "1",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         "82.6"
#       ]
#     },
#     {
#       "key": [
#         "35-44",
#         "2",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         "83.1"
#       ]
#     },
#     {
#       "key": [
#         "35-44",
#         "1+2",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         "82.8"
#       ]
#     },
#     {
#       "key": [
#         "45-54",
#         "1",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         "76.2"
#       ]
#     },
#     {
#       "key": [
#         "45-54",
#         "2",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         "74.8"
#       ]
#     },
#     {
#       "key": [
#         "45-54",
#         "1+2",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         "75.5"
#       ]
#     },
#     {
#       "key": [
#         "55-64",
#         "1",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         "67.7"
#       ]
#     },
#     {
#       "key": [
#         "55-64",
#         "2",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         "60.7"
#       ]
#     },
#     {
#       "key": [
#         "55-64",
#         "1+2",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         "64.5"
#       ]
#     },
#     {
#       "key": [
#         "sam20-64",
#         "1",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         "76.6"
#       ]
#     },
#     {
#       "key": [
#         "sam20-64",
#         "2",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         "75.7"
#       ]
#     },
#     {
#       "key": [
#         "sam20-64",
#         "1+2",
#         "1997",
#         "2022"
#       ],
#       "values": [
#         "76.2"
#       ]
#     }
#   ],
#   "metadata": [
#     {
#       "infofile": "AA0003",
#       "updated": "2023-12-22T07:00:00Z",
#       "label": "Andel förvärvsarbetande kommunmottagna flyktingar och anhöriga, procent efter ålder, kön, mottagningsår, sysselsättningsår och tabellinnehåll",
#       "source": "SCB"
#     }
#   ]
# }

# %%
folder_id = "AA0003"
folder = get_folder(folder_id)
print(json.dumps(folder, indent=2, ensure_ascii=False))
# Out:
# {
#   "language": "sv",
#   "id": "AA0003",
#   "label": "Registerdata för integration",
#   "description": "",
#   "folderContents": [
#     {
#       "type": "FolderInformation",
#       "id": "AA0003B",
#       "label": "Statistik med inriktning mot arbetsmarknaden",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/AA0003B?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "AA0003E",
#       "label": "Statistik med inriktning mot demografi",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/AA0003E?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "AA0003G",
#       "label": "Statistik med inriktning mot transfereringar",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/AA0003G?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "AA0003F",
#       "label": "Statistik med inriktning mot inkomster",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/AA0003F?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "AA0003D",
#       "label": "Statistik med inriktning mot boende",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/AA0003D?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "AA0003C",
#       "label": "Statistik med inriktning mot flyttmönster",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/AA0003C?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "AA0003H",
#       "label": "Statistik med inriktning mot utbildning",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/AA0003H?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "AA0003I",
#       "label": "Statistik med inriktning mot hälsa",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/AA0003I?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "AA0003J",
#       "label": "Statistik med inriktning mot val och valda",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/AA0003J?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "AA0003X",
#       "label": "Äldre tabeller som inte uppdateras",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/AA0003X?lang=sv"
#         }
#       ]
#     }
#   ],
#   "links": [
#     {
#       "rel": "self",
#       "hreflang": "sv",
#       "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/AA0003?lang=sv"
#     }
#   ]
# }

# %%
folder = get_folder()
print(json.dumps(folder, indent=2, ensure_ascii=False))
# Out:
# {
#   "language": "sv",
#   "id": "",
#   "label": "",
#   "description": "",
#   "folderContents": [
#     {
#       "type": "FolderInformation",
#       "id": "AM",
#       "label": "Arbetsmarknad",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/AM?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "BE",
#       "label": "Befolkning",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/BE?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "BO",
#       "label": "Boende, byggande och bebyggelse",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/BO?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "ME",
#       "label": "Demokrati",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/ME?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "EN",
#       "label": "Energi",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/EN?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "FM",
#       "label": "Finansmarknad",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/FM?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "HA",
#       "label": "Handel med varor och tjänster",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/HA?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "HE",
#       "label": "Hushållens ekonomi",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/HE?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "HS",
#       "label": "Hälso- och sjukvård",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/HS?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "JO",
#       "label": "Jord- och skogsbruk, fiske",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/JO?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "KU",
#       "label": "Kultur och fritid",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/KU?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "LE",
#       "label": "Levnadsförhållanden",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/LE?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "MI",
#       "label": "Miljö",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/MI?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "NR",
#       "label": "Nationalräkenskaper",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/NR?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "NV",
#       "label": "Näringsverksamhet",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/NV?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "OE",
#       "label": "Offentlig ekonomi",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/OE?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "PR",
#       "label": "Priser och konsumtion",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/PR?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "SO",
#       "label": "Socialtjänst",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/SO?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "TK",
#       "label": "Transporter och kommunikationer",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/TK?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "UF",
#       "label": "Utbildning och forskning",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/UF?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "AA",
#       "label": "Ämnesövergripande statistik",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/AA?lang=sv"
#         }
#       ]
#     },
#     {
#       "type": "FolderInformation",
#       "id": "OV",
#       "label": "Övrigt",
#       "description": "",
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/OV?lang=sv"
#         }
#       ]
#     }
#   ],
#   "links": [
#     {
#       "rel": "self",
#       "hreflang": "sv",
#       "href": "https://api.scb.se/OV0104/v2beta/api/v2/navigation/?lang=sv"
#     }
#   ]
# }

# %%
tables = get_tables(lang="sv")
print(json.dumps(tables, indent=2, ensure_ascii=False))
# Out:
# {
#   "language": "sv",
#   "tables": [
#     {
#       "type": "Table",
#       "id": "TAB4707",
#       "label": "Antal pågående anställningar efter anställningstid, kön och sektor. Månad 2020M01-2024M06",
#       "description": "",
#       "updated": "2024-09-04T06:00:00Z",
#       "firstPeriod": "2020M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "sektor",
#         "kön",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4707?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4707/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4707/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4707/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB4714",
#       "label": "Antal pågående anställningar efter anställningstid, sektor och näringsgren (SNI 2007). Månad 2020M01-2024M06",
#       "description": "",
#       "updated": "2024-09-04T06:00:00Z",
#       "firstPeriod": "2020M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "sektor",
#         "näringsgren (SNI 2007)",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4714?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4714/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4714/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4714/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB4718",
#       "label": "Antal pågående anställningar efter kön, region och sektor. Månad 2020M01-2024M06",
#       "description": "",
#       "updated": "2024-09-04T06:00:00Z",
#       "firstPeriod": "2020M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "region",
#         "kön",
#         "sektor",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4718?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4718/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4718/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4718/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB4723",
#       "label": "Antal pågående anställningar i näringslivet efter region och näringsgren (SNI 2007). Månad 2020M01-2024M06",
#       "description": "",
#       "updated": "2024-09-04T06:00:00Z",
#       "firstPeriod": "2020M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "region",
#         "bransch",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4723?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4723/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4723/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4723/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB4344",
#       "label": "Antal pågående anställningar i näringslivet efter anställningstid och näringsgren (SNI 2007). Månad 2020M01-2024M06",
#       "description": "",
#       "updated": "2024-09-04T06:00:00Z",
#       "firstPeriod": "2020M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "näringsgren (SNI 2007)",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4344?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4344/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4344/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4344/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB6348",
#       "label": "Antal pågående anställningar efter kön, sektor och näringsgren SNI2007. Månad 2020M01-2024M06",
#       "description": "",
#       "updated": "2024-09-04T06:00:00Z",
#       "firstPeriod": "2020M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "kön",
#         "sektor",
#         "näringsgren (SNI 2007)",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6348?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6348/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6348/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6348/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB6349",
#       "label": "Antal pågående anställningar i näringslivet efter kön och näringsgren (SNI 2007). Månad 2020M01-2024M06",
#       "description": "",
#       "updated": "2024-09-04T06:00:00Z",
#       "firstPeriod": "2020M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "kön",
#         "näringsgren (SNI 2007)",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6349?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6349/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6349/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6349/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB5462",
#       "label": "Sjukfrånvaro under sjuklöneperioden efter sektor och kön. Månad 2024M01-2024M06",
#       "description": "",
#       "updated": "2024-09-04T06:00:00Z",
#       "firstPeriod": "2024M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "sektor",
#         "kön",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB5462?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB5462/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB5462/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB5462/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB5434",
#       "label": "Sjukfrånvaro under sjuklöneperioden i näringslivet efter näringsgren (SNI 2007) och kön. Månad 2024M01-2024M06",
#       "description": "",
#       "updated": "2024-09-04T06:00:00Z",
#       "firstPeriod": "2024M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "näringsgren (SNI 2007)",
#         "kön",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB5434?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB5434/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB5434/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB5434/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB6396",
#       "label": "Sjukfrånvaro under sjuklöneperioden i offentlig förvaltning efter näringsgren (SNI 2007) och kön .  Månad 2024M01-2024M06",
#       "description": "",
#       "updated": "2024-09-04T06:00:00Z",
#       "firstPeriod": "2024M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "näringsgren (SNI 2007)",
#         "kön",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6396?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6396/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6396/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6396/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB5191",
#       "label": "Arbetad tid för pågående anställningar efter sektor och näringsgren (SNI 2007). Månad 2020M01-2024M06",
#       "description": "",
#       "updated": "2024-09-04T06:00:00Z",
#       "firstPeriod": "2020M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "sektor",
#         "näringsgren (SNI 2007)",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB5191?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB5191/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB5191/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB5191/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB6012",
#       "label": "Flöde i anställningar i näringslivet efter kön och näringsgren (SNI 2007). Månad 2020M01-2024M06",
#       "description": "",
#       "updated": "2024-09-04T06:00:00Z",
#       "firstPeriod": "2020M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "kön",
#         "näringsgren (SNI 2007)",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6012?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6012/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6012/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6012/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB6016",
#       "label": "Flöde i anställningar i näringslivet efter storleksklass och näringsgren (SNI 2007). Månad 2020M01-2024M06",
#       "description": "",
#       "updated": "2024-09-04T06:00:00Z",
#       "firstPeriod": "2020M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "storleksklass",
#         "bransch",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6016?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6016/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6016/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6016/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB6395",
#       "label": "Flöde i anställningar efter kön, sektor och näringsgren (SNI 2007). Månad 2020M01-2024M06",
#       "description": "",
#       "updated": "2024-09-04T06:00:00Z",
#       "firstPeriod": "2020M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "kön",
#         "sektor",
#         "näringsgren (SNI 2007)",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6395?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6395/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6395/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB6395/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB68",
#       "label": "Arbetskostnadsindex för arbetare, privat sektor (AKI) efter näringsgren enligt SNI 2007. Månad 2008M01-2024M06",
#       "description": "",
#       "updated": "2024-08-30T06:00:00Z",
#       "firstPeriod": "2008M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "näringsgren SNI 2007",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB68?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB68/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB68/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB68/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB72",
#       "label": "Arbetskostnadsindex för tjänstemän, privat sektor (AKI) efter näringsgren SNI 2007. Månad 2008M01-2024M06",
#       "description": "",
#       "updated": "2024-08-30T06:00:00Z",
#       "firstPeriod": "2008M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "näringsgren SNI 2007",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB72?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB72/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB72/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB72/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB2546",
#       "label": "Löneindex för arbetare, privat sektor (LÖI) efter näringsgren SNI 2007. Månad 2008M01-2024M06",
#       "description": "",
#       "updated": "2024-08-30T06:00:00Z",
#       "firstPeriod": "2008M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "näringsgren SNI 2007",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2546?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2546/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2546/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2546/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB2549",
#       "label": "Löneindex för tjänstemän, privat sektor (LÖI) efter näringsgren SNI 2007. Månad 2008M01-2024M06",
#       "description": "",
#       "updated": "2024-08-30T06:00:00Z",
#       "firstPeriod": "2008M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "näringsgren SNI 2007",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2549?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2549/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2549/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2549/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB67",
#       "label": "Arbetskostnadsindex för arbetare, privat sektor (AKIak) efter näringsgren enligt SNI 2002 (uppdateras ej). Månad 1996M01-2008M12",
#       "description": "",
#       "updated": "2009-03-02T08:30:00Z",
#       "firstPeriod": "1996M01",
#       "lastPeriod": "2008M12",
#       "category": "public",
#       "variableNames": [
#         "näringsgren SNI 2002",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB67?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB67/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB67/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB67/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB69",
#       "label": "Arbetskostnadsindex för industriarbetare (AKIam) efter näringsgren enligt SNI 2002 (uppdateras ej). Månad 1996M01-2008M12",
#       "description": "",
#       "updated": "2009-03-02T08:30:00Z",
#       "firstPeriod": "1996M01",
#       "lastPeriod": "2008M12",
#       "category": "public",
#       "variableNames": [
#         "näringsgren SNI 2002",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB69?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB69/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB69/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB69/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB71",
#       "label": "Arbetskostnadsindex för tjänstemän, privat sektor (AKItk) efter näringsgren SNI2002 (uppdateras ej). Månad 1996M01-2008M12",
#       "description": "",
#       "updated": "2009-03-02T08:30:00Z",
#       "firstPeriod": "1996M01",
#       "lastPeriod": "2008M12",
#       "category": "public",
#       "variableNames": [
#         "näringsgren SNI 2002",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB71?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB71/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB71/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB71/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB2545",
#       "label": "Löneindex för arbetare, privat sektor (LÖIak) efter näringsgren SNI2002 (uppdateras ej). Månad 1996M01-2008M12",
#       "description": "",
#       "updated": "2009-03-02T08:30:00Z",
#       "firstPeriod": "1996M01",
#       "lastPeriod": "2008M12",
#       "category": "public",
#       "variableNames": [
#         "näringsgren SNI 2002",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2545?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2545/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2545/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2545/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB2547",
#       "label": "Löneindex för industriarbetare (LÖI) efter näringsgren SNI2002 (uppdateras ej). Månad 1996M01-2008M12",
#       "description": "",
#       "updated": "2009-03-02T08:30:00Z",
#       "firstPeriod": "1996M01",
#       "lastPeriod": "2008M12",
#       "category": "public",
#       "variableNames": [
#         "näringsgren SNI 2002",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2547?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2547/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2547/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2547/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB2548",
#       "label": "Löneindex för tjänstemän, privat sektor (LÖItk) efter näringsgren SNI2002 (uppdateras ej). Månad 1996M01-2008M12",
#       "description": "",
#       "updated": "2009-03-02T08:30:00Z",
#       "firstPeriod": "1996M01",
#       "lastPeriod": "2008M12",
#       "category": "public",
#       "variableNames": [
#         "näringsgren SNI 2002",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2548?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2548/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2548/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2548/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB66",
#       "label": "Arbetskostnadsindex, arbetare och tjänstemän, privat sektor (AKI) efter näringsgren SNI92 (uppdateras ej). Kvartal 1994K1-1999K2",
#       "description": "",
#       "updated": "1999-11-09T10:34:00Z",
#       "firstPeriod": "1994K1",
#       "lastPeriod": "1999K2",
#       "category": "public",
#       "variableNames": [
#         "näringsgren SNI92",
#         "tabellinnehåll",
#         "kvartal"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB66?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB66/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB66/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB66/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB70",
#       "label": "Arbetskostnadsindex för industriarbetare (AKIam) efter näringsgren SNI92 (uppdateras ej). Kvartalsmittmånad 1994M02-2000M05",
#       "description": "",
#       "updated": "2000-07-31T08:00:00Z",
#       "firstPeriod": "1994M02",
#       "lastPeriod": "2000M05",
#       "category": "public",
#       "variableNames": [
#         "näringsgren SNI92",
#         "tabellinnehåll",
#         "kvartalsmittmånad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB70?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB70/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB70/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB70/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB2559",
#       "label": "Löneindex för industriarbetare (LÖI) efter näringsgren SNI92 (uppdateras ej). Kvartalsmittmånad 1994M02-2000M05",
#       "description": "",
#       "updated": "2000-07-31T08:00:00Z",
#       "firstPeriod": "1994M02",
#       "lastPeriod": "2000M05",
#       "category": "public",
#       "variableNames": [
#         "näringsgren SNI92",
#         "tabellinnehåll",
#         "kvartalsmittmånad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2559?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2559/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2559/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2559/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB3657",
#       "label": "Arbetskostnadsindex (AKI), förändring från motsvarande månad föregående år. Månad 2009M01-2024M06",
#       "description": "",
#       "updated": "2024-08-30T06:00:00Z",
#       "firstPeriod": "2009M01",
#       "lastPeriod": "2024M06",
#       "category": "public",
#       "variableNames": [
#         "ekonomisk indikator",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3657?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3657/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3657/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3657/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB4695",
#       "label": "Befolkningen 15-74 år (AKU) efter kön, ålder och arbetskraftstillhörighet. Månad 2001M01-2024M07",
#       "description": "",
#       "updated": "2024-08-23T06:00:00Z",
#       "firstPeriod": "2001M01",
#       "lastPeriod": "2024M07",
#       "category": "public",
#       "variableNames": [
#         "kön",
#         "ålder",
#         "arbetskraftstillhörighet",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4695?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4695/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4695/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4695/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB4692",
#       "label": "Befolkningen 15-74 år (AKU) efter kön, ålder och arbetskraftstillhörighet. Kvartal 2001K1-2024K2",
#       "description": "",
#       "updated": "2024-07-26T06:00:00Z",
#       "firstPeriod": "2001K1",
#       "lastPeriod": "2024K2",
#       "category": "public",
#       "variableNames": [
#         "kön",
#         "ålder",
#         "arbetskraftstillhörighet",
#         "tabellinnehåll",
#         "kvartal"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4692?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4692/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4692/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4692/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB4696",
#       "label": "Befolkningen 15-74 år (AKU) efter kön, ålder och arbetskraftstillhörighet. År 2001-2023",
#       "description": "",
#       "updated": "2024-04-24T06:00:00Z",
#       "firstPeriod": "2001",
#       "lastPeriod": "2023",
#       "category": "public",
#       "variableNames": [
#         "kön",
#         "ålder",
#         "arbetskraftstillhörighet",
#         "tabellinnehåll",
#         "år"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4696?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4696/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4696/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4696/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB4393",
#       "label": "Sysselsatta 15-74 år (AKU), därav i arbete samt därav frånvarande hela veckan efter kön och ålder.  Månad 2001M01-2024M07",
#       "description": "",
#       "updated": "2024-08-23T06:00:00Z",
#       "firstPeriod": "2001M01",
#       "lastPeriod": "2024M07",
#       "category": "public",
#       "variableNames": [
#         "kön",
#         "ålder",
#         "arbetskraftstillhörighet",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4393?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4393/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4393/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4393/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB4517",
#       "label": "Sysselsatta 15-74 år (AKU), därav i arbete samt därav frånvarande hela veckan efter kön och ålder.  Kvartal 2001K1-2024K2",
#       "description": "",
#       "updated": "2024-07-26T06:00:00Z",
#       "firstPeriod": "2001K1",
#       "lastPeriod": "2024K2",
#       "category": "public",
#       "variableNames": [
#         "kön",
#         "ålder",
#         "arbetskraftstillhörighet",
#         "tabellinnehåll",
#         "kvartal"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4517?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4517/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4517/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4517/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB4777",
#       "label": "Sysselsatta 15-74 år (AKU), därav i arbete samt därav frånvarande hela veckan efter kön och ålder.  År 2001-2023",
#       "description": "",
#       "updated": "2024-04-24T06:00:00Z",
#       "firstPeriod": "2001",
#       "lastPeriod": "2023",
#       "category": "public",
#       "variableNames": [
#         "kön",
#         "ålder",
#         "arbetskraftstillhörighet",
#         "tabellinnehåll",
#         "år"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4777?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4777/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4777/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4777/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB4778",
#       "label": "Sysselsatta 15-74 år (AKU) efter anknytningsgrad till arbetsmarknaden, kön och ålder.  Månad 2001M01-2024M07",
#       "description": "",
#       "updated": "2024-08-23T06:00:00Z",
#       "firstPeriod": "2001M01",
#       "lastPeriod": "2024M07",
#       "category": "public",
#       "variableNames": [
#         "kön",
#         "ålder",
#         "anknytningsgrad till arbetsmarknaden",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4778?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4778/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4778/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4778/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB4779",
#       "label": "Sysselsatta 15-74 år (AKU) efter anknytningsgrad till arbetsmarknaden, kön och ålder.  Kvartal 2001K1-2024K2",
#       "description": "",
#       "updated": "2024-07-26T06:00:00Z",
#       "firstPeriod": "2001K1",
#       "lastPeriod": "2024K2",
#       "category": "public",
#       "variableNames": [
#         "kön",
#         "ålder",
#         "anknytningsgrad till arbetsmarknaden",
#         "tabellinnehåll",
#         "kvartal"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4779?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4779/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4779/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4779/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB4780",
#       "label": "Sysselsatta 15-74 år (AKU) efter anknytningsgrad till arbetsmarknaden, kön och ålder.  År 2001-2023",
#       "description": "",
#       "updated": "2024-04-24T06:00:00Z",
#       "firstPeriod": "2001",
#       "lastPeriod": "2023",
#       "category": "public",
#       "variableNames": [
#         "kön",
#         "ålder",
#         "anknytningsgrad till arbetsmarknaden",
#         "tabellinnehåll",
#         "år"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4780?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4780/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4780/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4780/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB3015",
#       "label": "Sysselsatta 15-74 år (AKU) efter anknytningsgrad till arbetsmarknaden, näringsgren SNI2007 och kön. Månad 2005M01-2024M07",
#       "description": "",
#       "updated": "2024-08-23T06:00:00Z",
#       "firstPeriod": "2005M01",
#       "lastPeriod": "2024M07",
#       "category": "public",
#       "variableNames": [
#         "anknytningsgrad till arbetsmarknaden",
#         "näringsgren SNI 2007",
#         "kön",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3015?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3015/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3015/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3015/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB3014",
#       "label": "Sysselsatta 15-74 år (AKU) efter anknytningsgrad till arbetsmarknaden, näringsgren SNI2007 och kön. Kvartal 2005K1-2024K2",
#       "description": "",
#       "updated": "2024-07-26T06:00:00Z",
#       "firstPeriod": "2005K1",
#       "lastPeriod": "2024K2",
#       "category": "public",
#       "variableNames": [
#         "anknytningsgrad till arbetsmarknaden",
#         "näringsgren SNI 2007",
#         "kön",
#         "tabellinnehåll",
#         "kvartal"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3014?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3014/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3014/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3014/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB3013",
#       "label": "Sysselsatta 15-74 år (AKU) efter anknytningsgrad till arbetsmarknaden, näringsgren SNI2007 och kön. År 2005-2023",
#       "description": "",
#       "updated": "2024-04-24T06:00:00Z",
#       "firstPeriod": "2005",
#       "lastPeriod": "2023",
#       "category": "public",
#       "variableNames": [
#         "anknytningsgrad till arbetsmarknaden",
#         "näringsgren SNI 2007",
#         "kön",
#         "tabellinnehåll",
#         "år"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3013?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3013/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3013/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3013/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB4438",
#       "label": "Sysselsatta 15-74 år (AKU) efter anknytningsgrad till arbetsmarknaden, yrke SSYK 2012 och kön. Månad 2015M01-2024M07",
#       "description": "",
#       "updated": "2024-08-23T06:00:00Z",
#       "firstPeriod": "2015M01",
#       "lastPeriod": "2024M07",
#       "category": "public",
#       "variableNames": [
#         "anknytningsgrad till arbetsmarknaden",
#         "yrke",
#         "kön",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4438?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4438/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4438/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4438/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB4439",
#       "label": "Sysselsatta 15-74 år (AKU) efter anknytningsgrad till arbetsmarknaden, yrke SSYK 2012 och kön. Kvartal 2015K1-2024K2",
#       "description": "",
#       "updated": "2024-07-26T06:00:00Z",
#       "firstPeriod": "2015K1",
#       "lastPeriod": "2024K2",
#       "category": "public",
#       "variableNames": [
#         "anknytningsgrad till arbetsmarknaden",
#         "yrke",
#         "kön",
#         "tabellinnehåll",
#         "kvartal"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4439?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4439/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4439/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4439/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB4440",
#       "label": "Sysselsatta 15-74 år (AKU) efter anknytningsgrad till arbetsmarknaden, yrke SSYK 2012 och kön.  År 2015-2023",
#       "description": "",
#       "updated": "2024-04-24T06:00:00Z",
#       "firstPeriod": "2015",
#       "lastPeriod": "2023",
#       "category": "public",
#       "variableNames": [
#         "anknytningsgrad till arbetsmarknaden",
#         "yrke",
#         "kön",
#         "tabellinnehåll",
#         "år"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4440?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4440/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4440/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB4440/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB3028",
#       "label": "Sysselsatta som studerar 15-74 år (AKU) efter hel/deltidsstudier, kön och ålder. Månad 2005M01-2024M07",
#       "description": "",
#       "updated": "2024-08-23T06:00:00Z",
#       "firstPeriod": "2005M01",
#       "lastPeriod": "2024M07",
#       "category": "public",
#       "variableNames": [
#         "hel/deltidsstudier",
#         "kön",
#         "ålder",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3028?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3028/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3028/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3028/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB3027",
#       "label": "Sysselsatta som studerar 15-74 år (AKU) efter hel/deltidsstudier, kön och ålder. Kvartal 2005K1-2024K2",
#       "description": "",
#       "updated": "2024-07-26T06:00:00Z",
#       "firstPeriod": "2005K1",
#       "lastPeriod": "2024K2",
#       "category": "public",
#       "variableNames": [
#         "hel/deltidsstudier",
#         "kön",
#         "ålder",
#         "tabellinnehåll",
#         "kvartal"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3027?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3027/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3027/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3027/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB3026",
#       "label": "Sysselsatta som studerar 15-74 år (AKU) efter hel/deltidsstudier, kön och ålder. År 2005-2023",
#       "description": "",
#       "updated": "2024-04-24T06:00:00Z",
#       "firstPeriod": "2005",
#       "lastPeriod": "2023",
#       "category": "public",
#       "variableNames": [
#         "hel/deltidsstudier",
#         "kön",
#         "ålder",
#         "tabellinnehåll",
#         "år"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3026?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3026/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3026/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB3026/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB2992",
#       "label": "Sysselsatta som studerar 15-74 år (AKU) - genomsnittligt antal arbets-/studietimmar per vecka samt antal sysselsatta efter kön och ålder. Månad 2005M01-2024M07",
#       "description": "",
#       "updated": "2024-08-23T06:00:00Z",
#       "firstPeriod": "2005M01",
#       "lastPeriod": "2024M07",
#       "category": "public",
#       "variableNames": [
#         "kön",
#         "ålder",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2992?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2992/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2992/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2992/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB2991",
#       "label": "Sysselsatta som studerar 15-74 år (AKU) - genomsnittligt antal arbets-/studietimmar per vecka samt antal sysselsatta efter kön och ålder. Kvartal 2005K1-2024K2",
#       "description": "",
#       "updated": "2024-07-26T06:00:00Z",
#       "firstPeriod": "2005K1",
#       "lastPeriod": "2024K2",
#       "category": "public",
#       "variableNames": [
#         "kön",
#         "ålder",
#         "tabellinnehåll",
#         "kvartal"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2991?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2991/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2991/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2991/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB2990",
#       "label": "Sysselsatta som studerar 15-74 år (AKU) - genomsnittligt antal arbets-/studietimmar per vecka samt antal sysselsatta efter kön och ålder. År 2005-2023",
#       "description": "",
#       "updated": "2024-04-24T06:00:00Z",
#       "firstPeriod": "2005",
#       "lastPeriod": "2023",
#       "category": "public",
#       "variableNames": [
#         "kön",
#         "ålder",
#         "tabellinnehåll",
#         "år"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2990?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2990/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2990/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB2990/data?lang=sv&outputFormat=px"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "id": "TAB670",
#       "label": "Sysselsatta 15-74 år (AKU), i arbete, efter arbete hemifrån i referensveckan, kön och ålder. Månad 2022M07-2024M07",
#       "description": "",
#       "updated": "2024-08-23T06:00:00Z",
#       "firstPeriod": "2022M07",
#       "lastPeriod": "2024M07",
#       "category": "public",
#       "variableNames": [
#         "arbete hemifrån (referensveckan)",
#         "kön",
#         "ålder",
#         "tabellinnehåll",
#         "månad"
#       ],
#       "links": [
#         {
#           "rel": "self",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB670?lang=sv"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB670/metadata?lang=sv&outputFormat=json-px"
#         },
#         {
#           "rel": "metadata",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB670/metadata?lang=sv&outputFormat=json-stat2"
#         },
#         {
#           "rel": "data",
#           "hreflang": "sv",
#           "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/TAB670/data?lang=sv&outputFormat=px"
#         }
#       ]
#     }
#   ],
#   "page": {
#     "pageNumber": 1,
#     "pageSize": 50,
#     "totalElements": 4992,
#     "totalPages": 100,
#     "links": [
#       {
#         "rel": "next",
#         "hreflang": "sv",
#         "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/?lang=sv&pagesize=50&pageNumber=2"
#       },
#       {
#         "rel": "last",
#         "hreflang": "sv",
#         "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/?lang=sv&pagesize=50&pageNumber=100"
#       }
#     ]
#   },
#   "links": [
#     {
#       "rel": "self",
#       "hreflang": "sv",
#       "href": "https://api.scb.se/OV0104/v2beta/api/v2/tables/?lang=sv&pagesize=50&pageNumber=1"
#     }
#   ]
# }
